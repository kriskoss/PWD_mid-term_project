# %% [markdown]
# ## INDEX
# Go to:<br>
# [Acquiring initial data](#Acquiring_initial_data)<br>
# [Downloading data](#Downloading_data)<br>
# [Initial_analysis of the data](#Initial_analysis)<br>
# [AIRPORTS_analysis](#AIRPORTS_analysis)<br>
# [PSGR_vs_GDP](#PSGR_vs_GDP)<br>
# [Year_2018](#Year_2018)<br>

# %% [markdown]
# # Mid term project
# ## My goal
#
# I am interested in analysis of the field related to the aviation. My current job is related to this industry that is why it may be of special intrest to me. Selectoion of the dataset is more due to the curiosity then for any practical reason. One practical side effect of this work will be cleaning data which I will be albe to use outside of this project  I am interested is there any corelation to the size and GDP of country to its air passanger traffic. Also I am interested to see how covid affected those relations. In the process I am coursious if I will find some interesting data related to the passenger traffic and airports themselves. As an additional activity I will also analysie the physical properites of the runwaays on each airport. I expect to find some corelation in regard to civilian and military airports

# %% [markdown]
# ## Acquiring initial data <a id='Acquiring_initial_data'></a>🔗

# %%
import requests
import pandas as pd
import numpy as np
import shutil
import os
import re
import inspect

## Importing modules for PLOTTING
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# %% [markdown]
# ##### Functions

# %%
def add_func_name():
    if True:
        return '\n\t\t("'+inspect.currentframe().f_back.f_code.co_name+'" function.)'

# %%
def print_red(text):
    red_text = f"\033[91m{text}\033[0m"
    print(red_text)

# %%
def max_col_OFF():
    pd.set_option('display.max_columns', None) # Removing restriction on the number of columns to display
    
def max_col_ON():
    pd.reset_option('display.max_columns')

# %%
def max_rows_OFF():
    pd.set_option('display.max_rows', None)

def max_rows_ON():
    pd.reset_option("display.max_rows")

# %%
def download_file(filename,request):
    if re.search(r"Backup_data", filename)==None and (request.status_code == 200):
        with open(filename, 'wb') as f:
            f.write(request.content)
#             print(f'"{filename}" downloaded.'+add_func_name())

# %%
def try_to_download_file(filename, response):
    try:
        response.raise_for_status()
        data_folder = "Data"
        file_path= "/".join([data_folder, filename])
    
#         print(f'Request was successful. \n"{filename}" can be downloaded.'+ add_func_name() )

    except requests.HTTPError as e:
        file_path = "/".join(["Backup_data", filename])
        print(print_red('An error occurred:' + str(e)))
        print(print_red(f'Use backup file: {file_path}'))

    return file_path

# %%
def save_and_return_dataframe_from_csv(filename,request):
    download_file(filename,request)
    df = pd.read_csv(filename)
    print(f'"{filename}" saved and read into the DataFrame.' + add_func_name())  
    return df

# %%
def extract_zip(zip_file):
    data_folder = "__".join(["Extracted", zip_file[:-4]])
    data_folder_path = "/".join(["Data",data_folder])
    
    zip_file_path = "/".join(["Data",zip_file])
    # Create folder for extracted files if do not exists
    os.makedirs(data_folder_path, exist_ok=True) 
    
    # Unzip ZIP file
    if os.path.exists(zip_file_path):
        shutil.unpack_archive(zip_file_path, data_folder_path,'zip')     
        print(f'"{zip_file}" extracted into \\{data_folder_path} ' + add_func_name())
    else:
        zip_file_path = "/".join(["Backup_data",zip_file])
        shutil.unpack_archive(zip_file_path, data_folder_path,'zip')     
        
        print(print_red(f"USING BACKUP FILE: {zip_file_path}"))
    
    
    return data_folder_path

# %%
def return_data_filename__worldbank(search_string, data_folder):
    files = shutil.os.listdir(data_folder)
    for f_name in files:
        if re.search(search_string, f_name) and not re.match(r"Metadata", f_name):
#             print("CSV data filename selected." + add_func_name())
            return f_name
    print("ERROR: No match." + add_func_name())
    return None

# %%
def get_worldbank_zip_into_csv_data_file_path(key_string, zip_filename):
    "key_string - is the string which is specific for the worldbank CSV data extracted for specific indicator"
    
    # Extracting zip file and passing extract folder
    extract_folder = extract_zip(zip_filename)
    
    # Finding csv data file and returning CSV data file name
    data_filename = return_data_filename__worldbank(key_string, extract_folder)
    file_path='/'.join([extract_folder,data_filename])
    
    # Returning relative path to the CSV data file
#     print(f'The CSV data path is: "{file_path}"' + add_func_name())
    return file_path

# %%
# Removing rows which do not represent countries
def remove_not_country_rows(df):
    return df[df['Country Code'].isin(countries['alpha-3'])]

# %% [markdown]
# ## Downloading data <a id='Downloading_data'></a> 🔗

# %% [markdown]
# ### Countries list

# %% [markdown]
# something to scrabe - country prefixes: https://en.wikipedia.org/wiki/ICAO_airport_code
# Would be useful to add the continents for the runways data - many continents indicator missing. Using "country" list and the country name related to each "prefix" it may be possible to fix that data.
#
# I have noticed that more data i have, more ideas to explore appear.

# %%
countries_raw = pd.read_csv("Static_data/countries.csv")

# Keep only country name and 3-letter country code
countries = pd.DataFrame(countries_raw, columns=["name","alpha-3"])

# %% [markdown]
# ### Airports data

# %%
# Creating data folder
os.makedirs("Data", exist_ok=True)

# %%
## Getting airport database
URL1 = "https://ourairports.com/airports.csv"
response1 = requests.get(URL1)

# %%
filename = "airports_databas_raw.csv"
file_path = try_to_download_file(filename, response1)
airports= save_and_return_dataframe_from_csv(file_path, response1)
airports.shape
# Out:
# "Data/airports_databas_raw.csv" saved and read into the DataFrame.
# 		("save_and_return_dataframe_from_csv" function.)
# (35162, 23)

# %% [markdown]
# ### Runways data

# %%
# Getting runway data
URL2 = 'https://davidmegginson.github.io/ourairports-data/runways.csv'
response2 = requests.get(URL2)

filename ='runways_raw.csv'
file_path = try_to_download_file(filename, response2)
runways = save_and_return_dataframe_from_csv(file_path, response2)
runways.shape
# Out:
# "Data/runways_raw.csv" saved and read into the DataFrame.
# 		("save_and_return_dataframe_from_csv" function.)
# (44928, 20)

# %% [markdown]
# ### WORLD BANK - Passengers traffic per country (PSGR)

# %%
## Common parameters for all data downloaded from World Bank website
params={
    'downloadformat':'csv'
    }

# %%
URL3='https://api.worldbank.org/v2/en/indicator/IS.AIR.PSGR'
response3 = requests.get(URL3,params=params)
response3.url
# Out:
# 'https://api.worldbank.org/v2/en/indicator/IS.AIR.PSGR?downloadformat=csv'

# %%
filename = "worldbank_PSGR.zip"
file_path = try_to_download_file(filename, response3)

download_file(file_path, response3)

file_path = get_worldbank_zip_into_csv_data_file_path("PSGR", filename)

worldbank_PSGR_raw = pd.read_csv(file_path, skiprows=3)
worldbank_PSGR_raw.shape
# Out:
# "worldbank_PSGR.zip" extracted into \Data/Extracted__worldbank_PSGR
# 		("extract_zip" function.)
# (266, 68)

# %% [markdown]
# ### WORLD BANK - GDP per capita (GDP_PCAP)
# https://data.worldbank.org/indicator/NY.GDP.PCAP.CD

# %%
URL4 = "https://api.worldbank.org/v2/en/indicator/NY.GDP.PCAP.KD"
response4 = requests.get(URL4, params=params)
response4.url
# Out:
# 'https://api.worldbank.org/v2/en/indicator/NY.GDP.PCAP.KD?downloadformat=csv'

# %%
filename = "worldbank_GDP_PCAP.zip"
file_path = try_to_download_file(filename, response4)

download_file(file_path, response4)

file_path = get_worldbank_zip_into_csv_data_file_path("PCAP", filename)

worldbank__GDP_PCAP_raw = pd.read_csv(file_path, skiprows=3)
worldbank__GDP_PCAP_raw.shape
# Out:
# "worldbank_GDP_PCAP.zip" extracted into \Data/Extracted__worldbank_GDP_PCAP
# 		("extract_zip" function.)
# (266, 68)

# %% [markdown]
# ### WORLD BANK - population

# %%
URL5 = "https://api.worldbank.org/v2/en/indicator/SP.POP.TOTL"
response5 = requests.get(URL5, params=params)
response5.url
# Out:
# 'https://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv'

# %%
filename = "worldbank_POP_TOTL.zip"
file_path = try_to_download_file(filename, response5)

download_file(file_path, response5)

file_path = get_worldbank_zip_into_csv_data_file_path("POP", filename)

worldbank__POP_raw = pd.read_csv(file_path, skiprows=3)
worldbank__POP_raw.shape
# Out:
# "worldbank_POP_TOTL.zip" extracted into \Data/Extracted__worldbank_POP_TOTL
# 		("extract_zip" function.)
# (266, 68)

# %% [markdown]
# ### WORLD BANK - Countries surface areas
# https://data.worldbank.org/indicator/AG.SRF.TOTL.K2

# %%
URL6 = "https://api.worldbank.org/v2/en/indicator/AG.SRF.TOTL.K2"
    
response6 = requests.get(URL6, params=params)
response6.url
# Out:
# 'https://api.worldbank.org/v2/en/indicator/AG.SRF.TOTL.K2?downloadformat=csv'

# %%
filename = "worldbank_SRF_TOTL.zip"
file_path = try_to_download_file(filename, response6)

download_file(file_path, response6)

file_path = get_worldbank_zip_into_csv_data_file_path("SRF", filename)

worldbank__SURF_raw = pd.read_csv(file_path, skiprows=3)
worldbank__SURF_raw.shape
# Out:
# "worldbank_SRF_TOTL.zip" extracted into \Data/Extracted__worldbank_SRF_TOTL
# 		("extract_zip" function.)
# (266, 68)

# %% [markdown]
# ### Worldbank Gross Domestic Product
# https://data.worldbank.org/indicator/NY.GDP.MKTP.CD

# %%
URL7 = "https://api.worldbank.org/v2/en/indicator/NY.GDP.MKTP.CD"
    
response7 = requests.get(URL7, params=params)
response7.url
# Out:
# 'https://api.worldbank.org/v2/en/indicator/NY.GDP.MKTP.CD?downloadformat=csv'

# %%
filename = "worldbank_GDP.zip"
file_path = try_to_download_file(filename, response6)

download_file(file_path, response7)

file_path = get_worldbank_zip_into_csv_data_file_path("GDP", filename)

worldbank__GDP_raw = pd.read_csv(file_path, skiprows=3)
worldbank__GDP_raw.shape
# Out:
# "worldbank_GDP.zip" extracted into \Data/Extracted__worldbank_GDP
# 		("extract_zip" function.)
# (266, 68)

# %% [markdown]
# ### Our World in Data
# https://ourworldindata.org/grapher/political-regime

# %%
legend = {
    0:"Closed autocracy",
    1:"Electoral autocracy",
    2:"Electoral democracy",
    3:"Liberal democracy",
}
regime = pd.read_csv("Static_data/political_regime.csv")   
regime.shape
# print(regime)
# Out:
# (30766, 4)

# %%
regime_wide = regime.pivot(index='Entity', columns='Year', values='regime_row_owid')
# print(regime_wide)

# %% [markdown]
# # Initial analysis of the data <a id='Initial_analysis'></a>🔗

# %% [markdown]
# Each downloaded World Bank csv file contains rows which actually are not countries, they may represent some regions or other aspects. The function used below removes those rows that contain non-country data

# %%
worldbank__GDP =  remove_not_country_rows(worldbank__GDP_raw)
worldbank__GDP_PCAP = remove_not_country_rows(worldbank__GDP_PCAP_raw)
worldbank__SURF = remove_not_country_rows(worldbank__SURF_raw)
worldbank__PSGR = remove_not_country_rows(worldbank_PSGR_raw)
worldbank__POP = remove_not_country_rows(worldbank__POP_raw)

# %% [markdown]
# At this point there are following dataframes uploaded into memory:
#     airports - contains world airport data
#     runways - contains more precise data related to the runways at each airport, such as length and width of the runway
#     worldbank_PSGR - Passengers traffic per country data
#     worldbank__GDP_PCAP - contains Gross Domestic product per capita for most of the countries

# %%
# Checking the Ai
# [item for item in airports.head(0)]

# %%
# Exploring how the data looks like
# airports.head(2)

# %%
# [item for item in runways.head(0)]

# %%
# Testing access to selected airport by its 4-letter ICAO code. In this case EPWA means Warsaw Chopin Airport , Poland
airport_ident = 'EPWA'
df = runways
# Boolean indexing to filter rows
filtered_rows = df[df['airport_ident'] == airport_ident]
# filtered_rows

# %% [markdown]
# ### Getting GDP per capita
# By looking at the general chart of passenger numbers by country and my general knowledge regarding GDP of each country it is possible that the some kind of factor POPULATIONxGDP may infulence the passenger travel in some regions
#
# Selection of the GDP per capita type:
#
# "Comparisons of national wealth are frequently made on the basis of nominal GDP and savings (not just income), which do not reflect differences in the cost of living in different countries (see List of countries by GDP (nominal) per capita); hence, using a PPP basis is arguably more useful when comparing generalized differences in living standards between economies because PPP takes into account the relative cost of living and the inflation rates of the countries, rather than using only exchange rates, which may distort the real differences in income."
# Wikipedia , accesed on 06.07.2023 (https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(PPP)_per_capita)

# %% [markdown]
# ### PSGR vs GDP analysis <a id="PSGR_vs_GDP"></a> 🔗

# %% [markdown]
# Here my goal is to compara passanger numbers traveling in a country to the coutries GDP. Next I will compare the to GDP per capita. One more type of comparission that includes gdp per capita nad the total population. As a reference I will compare data in 2018 which is the time before COVID pandemics.

# %%
def plot_GDP_PSGR_2018_align_factor(df):
    df['GDP_to_PSGR_2018'].plot(kind='bar', figsize=(14, 8))
    plt.title('GDP-to-Passenger Align Factor for Each Country')
    plt.ylabel('Align Factor')
    plt.xlabel('Country')
    plt.xticks(rotation=90)  # rotate x-axis labels for better visibility
    plt.show()

# %%
def get_series_for_selected_year(df,year):
    # This works only for selected World Bank CSV files
    year = str(year)
    
    series = pd.Series(df[year])
    series.index = df['Country Name']
    
    # Convert values to int and handle NaN values
    series = series.apply(lambda x: int(x) if pd.notna(x) else x)
    
    return series

# %%
def generate_value(row, colA, colB, reference_ratio):
    if row[colA]/(row[colB]*reference_ratio) > 1:
        align_factor = 1+(row[colA] / (row[colB] * -reference_ratio))
    else:
        align_factor = -1+(row[colB] / row[colA] * reference_ratio)
    return align_factor.round(2)

def generate_align_factor(df,colA,colB,ref_country=None,outputColName=None,): #generate_align_factor
    """
    df - that need to contain col A and B and index that is 'Country Name
    colA,colB - column names to coalculate the factor (e.g. GDP_2018, SURF_2018)
    ref - reference "Country Name" (e.g Canada)
    
    returns: df,reference_ratio, numA, numB
    numA,numB - those are values for colA and colB of the reference country
    """
    # Compare
    if outputColName:
        newName=outputColName
    else:
        partA = re.sub("_\d{4}", "", colA)
        newName = '_'.join([partA,'to',colB])
    
    # Calculate reference's country a reference ratio (GDP/passengers)
    # numA and numB are the values for reference country (i.e. Canada) and the respective columns(i.e. GDP and PSGR)
    if ref_country:
        
        numA = df.loc[ref_country, colA]
        numB = df.loc[ref_country, colB]
        reference_ratio = numA / numB
        
    else: 
        numA = None
        numB = None
        reference_ratio=1
    
    # Calculate ratio for each country and divide by reference ratio
#     df[newName] = df.apply(lambda row: 1+(row[colA] / (row[colB] * -reference_ratio)) if row[colA]/(row[colB]*reference_ratio) > 1
#                         else -1+(row[colB] / row[colA] * reference_ratio), axis=1)
    df[newName] = df.apply(generate_value, args=(colA, colB, reference_ratio), axis=1)
    
    return df,reference_ratio, numA, numB

# %%
def print_column_info(column):
    return column.idxmin(), column.idxmax()

# %%
def print_world_population_factor(world_pop_in_year, pop_column, prnt=True):
    factor = pop_column.sum()/world_pop_in_year
    
    if prnt:
        print('{:.0%}'.format(factor)+f' of world population in year {year}', add_func_name())
    
    return factor

# %%
## Stores dropped rows for which factor is exceeded
def exclude_to_high_factor_countries(df,factor_col_name, factor):
    countries_to_exclude = df[(df[factor_col_name]< -factor) | (df[factor_col_name]> factor)
        ].index.tolist()
    
    df_copy = df.copy() # To avoid modification of the original data
    
    # Drop the rows
    df_adjusted = df_copy.drop(countries_to_exclude)
    
    # Creating a dataframe of dropped rows
    dropped_countries_df = df_copy.loc[countries_to_exclude]
    
    """ 
    Returns the:
            - the original dataframe, 
            - the adjusted dataframe - the data frame which do not contain any more countries below the threshold
            - the dataframe of dropped rows
    """
    
    return df, df_adjusted, dropped_countries_df

# %%
def df_row__float_to_int(df,index_name):
    # Transpose the DataFrame
    df_t = df.transpose()
    
    # Convert the 'count' column to integers
    df_t[index_name] = df_t[index_name].astype(int)

    # Transpose back to the original structure
    df = df_t.transpose()
    
    return df

# %%
def df_row__float_to_decimal_pts(df, index_name, decimal_pts): 
    # Transpose the DataFrame
    df_t = df.transpose()

    # Convert the 'world_pop_fract' column to percentage, round to 0 decimal digits, and convert to string
    df_t[index_name] = df_t[index_name].apply(lambda x: round(x,decimal_pts) if isinstance(x, float) else x)

    # Transpose back to the original structure
    df = df_t.transpose()
    
    return df

# %%
def df_row__float_to_percent(df, index_name, decimal_pts=0): #df_row__float_to_percent
    """
    Converts the values in a specific row of dataframe to %.
    
    df(Dataframe) -the input dataframe.
    index_name (str): The name of the row to convert to percentages.
    decimal_pts (int, optional): The default is 0 . Number of decimal points to round the percentages to.,

    Returns converted dataframe
    """
    df_t = df.transpose()

    # Define a conversion function that handles different cases based on value
    def convert_to_percentage(x):
        if abs(x) > 0.01 :
            return str(int(x * 100)) + '%'
        else:
            return str(round(x * 100, 1)) + '%'
        
    # Convert the specified row values to percentages
    df_t[index_name] = df_t[index_name].apply(convert_to_percentage)

    # Transpose back to the original structure
    df = df_t.transpose()
    
    return df

# %%
def plot_one_vs_other(df, colA, colB, ref_country, ref_LEFT, ref_RIGHT,colorA="darkslateblue", colorB="orange", title=None):
    """
    df - dataframe that need to contain index "Country Name"
    colA,colB - column names which will be plotted next to each other (e.g GDP_2018, PSGR_2018
    ref_country - ref_countryerence country name (e.g "Canada")
    
    #plot_one_vs_other
    """
    # Create a list of colors for GDP plot
    colA_colors = ['red' if index == ref_country else colorA for index in df.index]
    colB_colors = ['blue' if index == ref_country else colorB for index in df.index]

    # Create a bar plot for GDP
    fig, ax1 = plt.subplots(figsize=(14, 8))
    df[colA].plot(kind='bar', color=colA_colors, ax=ax1, label=colA)

    # Create a new y-axis for PSGR on the right side
    ax2 = ax1.twinx()
    df[colB].plot(kind='bar', color=colB_colors, ax=ax2, alpha=0.5, label=colB)

    # Set title and labels
    if not title:
        title = f'{colA} vs {colB} in {year}'
    plt.title(title)
    ax1.set_ylabel(f'{colA} in [units]')
    ax2.set_ylabel(f'{colB} in [units]')

    # Find maximum value in colA and compute corresponding limit for colB
    
#     # Getting reference values for colA nad colB and the reference country
#     ref_LEFT = df.loc[ref_country,colA]
#     ref_RIGHT = df.loc[ref_country,colB]

    # Finding factor of max value in column to the referecne value - this enables comparison of differnent values
    colA_factor = df[colA].max()/ref_LEFT
    colB_factor = df[colB].max()/ref_RIGHT
    
  
    # Factor used depends if factor for colA or colB is larger - the larger factor will be then used on both, left and right scales
    if colA_factor < colB_factor:
        factor = colB_factor
    else:
        factor= colA_factor

    ax1.set_ylim(0, ref_LEFT*factor*1.1)
    ax2.set_ylim(0, ref_RIGHT*factor*1.1)
        

    # Change color of ref_country label to red
    for label in ax1.get_xticklabels():
        if label.get_text() == ref_country:
            label.set_color('red')

    # Add legends
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')

# %%
def str_to_percentage(key):
    return str(int(round(float(key) * 100)))+'%'

# %%
def normalize_to_plot(df,colA,colB, fact1,fact2):
    df_copy = df.copy()
    df_copy[colA] = df_copy[colA] / fact1 # Convert to trillions
    df_copy[colB] = df_copy[colB] / fact2 # Convert to hundreds of millions    

    return df_copy

# %%
def keep_selected_columns(df, *cols_to_keep): #keep_selected_columns
    new_df = df[[col for col in df.columns if col in cols_to_keep]]
    new_df = new_df.reindex(columns=cols_to_keep)
    return new_df

# %%
##REF2
def plot_GDP_vs_PSGR(df,colorA="darkslateblue",colorB="orange"):
    # Create a list of colors for GDP plot
    gdp_colors = ['red' if index == 'Canada' else colorA for index in df.index]
    psg_colors = ['blue' if index == 'Canada' else colorB for index in df.index]

    # Create a bar plot for GDP
    fig, ax1 = plt.subplots(figsize=(14, 8))
    df['GDP_2018'].plot(kind='bar', color=gdp_colors, ax=ax1, label='GDP (in trillions)')

    # Create a new y-axis for PSGR on the right side
    ax2 = ax1.twinx()
    df['PSGR_2018'].plot(kind='bar', color=psg_colors, ax=ax2, alpha=0.5, label='Passengers (in hundreds of millions)')

    # Set title and labels
    plt.title('GDP and Passenger numbers for 2018')
    ax1.set_ylabel('GDP (in trillions)')
    ax2.set_ylabel('Passengers (in hundreds of millions)')

    # Find maximum value in 'GDP_2018' and compute corresponding limit for 'PSGR_2018'
    
    
    max_gdp = df['GDP_2018'].max()
    max_psg = df['PSGR_2018'].max()
    
    # Selecting ylim for the plot - the larger among GDP and PSGR is selected after using correction
    if max_psg < max_gdp:
        max_val = max_gdp 
        ax1.set_ylim(0, max_gdp*1.1)
        ax2.set_ylim(0, max_val*1.1)
        
    else:
        ax1.set_ylim(0, max_psg*1.1)
        ax2.set_ylim(0, max_psg*1.1)    

    # Change color of 'Canada' label to red
    for label in ax1.get_xticklabels():
        if label.get_text() == 'Canada':
            label.set_color('red')

    # Add legends
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')

# %% [markdown]
# #        Year 2018  <a id="Year_2018">🔗</a>

# %% [markdown]
# ## GDP to PSGR

# %% [markdown]
# ##### Gettig data

# %%
year = 2018

# Getting series for y2018
POP_2018 = get_series_for_selected_year(worldbank__POP,year)
GDP_2018 = get_series_for_selected_year(worldbank__GDP,year)
GDP_PCAP_2018 = get_series_for_selected_year(worldbank__GDP_PCAP, year)
PSGR_2018 = get_series_for_selected_year(worldbank__PSGR,year)
SURF_2018 = get_series_for_selected_year(worldbank__SURF, year)


# Getting worlds population
world_row = worldbank__POP_raw[(worldbank__POP_raw['Country Name'] == 'World')]
world_pop_2018 = int(world_row[str(year)].values[0])
print(f'World population in year {year}: {world_pop_2018}')
# Out:
# World population in year 2018: 7661776612

# %% [markdown]
# ##### Combining data

# %%
# CONCATENATING series
data_2018 = pd.concat([POP_2018, SURF_2018, GDP_PCAP_2018,GDP_2018, PSGR_2018], 
                          axis=1, 
                          keys=['POP_2018','SURF_2018','GDP_PCAP_2018','GDP_2018', 'PSGR_2018'])

# Droppin NaNs
data_2018.dropna(inplace=True)

# Generating align factor
data_2018, refRatioGDP_to_PSGR2018, _, _ = generate_align_factor(data_2018,'GDP_2018','PSGR_2018','Canada')    

# max_rows_ON()
# data_2018.sort_values(by="Country Name")

# %% [markdown]
# For all countries the factor DGP to PSG is -10,meaning that taking GDP of Canada to its Passenger number as a reference, the nubmer of passengers traveled from the country is ten times less in relation to its GDP when compared to the Canade.
#
# When trying to exclude the countries which has very large factor I can see what effect this got

# %% [markdown]
# ##### Limiting data to countries with factor  outside -2.5  to 2.5 range

# %%
ithr1=2.5
ithr2=1
ithr3=0.25
thr1=str(ithr1)
thr2=str(ithr2)
thr3=str(ithr3)
num_thrs =3


EDA_results={
    '2018':{
        'world_pop': world_pop_2018,
        'GDP_vs_PSGR':{
            'adjusted':{},
            'dropped':{},
            'Series':{},
            'world_pop_fract':{},
        }
    }
}

# Update world population 
world_pop = EDA_results['2018']['world_pop']

# Simplifying dict paths
GDPvsPSGR = EDA_results['2018']['GDP_vs_PSGR']
adjusted = EDA_results['2018']['GDP_vs_PSGR']['adjusted']
dropped = EDA_results['2018']['GDP_vs_PSGR']['dropped']
series = EDA_results['2018']['GDP_vs_PSGR']['Series']

# Dropping countries outside the acceptable range
_, adjusted[thr1], dropped[thr1] = exclude_to_high_factor_countries(data_2018,'GDP_to_PSGR_2018',ithr1)
_, adjusted[thr2], dropped[thr2]  = exclude_to_high_factor_countries(data_2018,'GDP_to_PSGR_2018',ithr2)
_, adjusted[thr3], dropped[thr3]  = exclude_to_high_factor_countries(data_2018,'GDP_to_PSGR_2018',ithr3)

# Describing each Series
series[thr1] = pd.Series(adjusted[thr1]['GDP_to_PSGR_2018'].describe().round(2))
series[thr2] = pd.Series(adjusted[thr2]['GDP_to_PSGR_2018'].describe().round(2))
series[thr3] = pd.Series(adjusted[thr3]['GDP_to_PSGR_2018'].describe().round(2))


# Iterate through the keys in the 'Series' dictionary and update 'idxmin' and 'idxmax'
for key in series.keys():
    series[key] = pd.concat([series[key], pd.Series([adjusted[key]['GDP_to_PSGR_2018'].idxmin()],index=['idxmin'])])
    series[key] = pd.concat([series[key], pd.Series([adjusted[key]['GDP_to_PSGR_2018'].idxmax()],index=['idxmax'])])

# Calculate fraction fo the population that adjusted dataframe contains
for key in adjusted.keys():
    # Getting new row value and index
    world_pop_fraction = print_world_population_factor(world_pop, adjusted[key]['POP_2018'], prnt=False)
    newIndex = 'world_pop_fract'
    
    # Creating single row Series
    newRow = pd.Series([world_pop_fraction], index=[newIndex])
    
    # Adding single row Series to the original data
    series[key] = pd.concat([series[key], newRow])

# %%
GDP_vs_PSGR_2018results = pd.concat([s for s in series.values()],axis=1, keys=[str_to_percentage(key) for key in series.keys()])
GDP_vs_PSGR_2018results = df_row__float_to_int(GDP_vs_PSGR_2018results,"count")
GDP_vs_PSGR_2018results = df_row__float_to_percent(GDP_vs_PSGR_2018results,"world_pop_fract")

GDP_vs_PSGR_2018results
# Out:
#                      250%        100%            25%
# count                 117          75             39
# mean                 0.01        0.05           0.02
# std                  1.11        0.46           0.13
# min                 -2.44       -0.92          -0.22
# 25%                 -0.54        -0.2          -0.09
# 50%                  0.07        0.05            0.0
# 75%                  0.72         0.3           0.14
# max                  2.18        0.94           0.25
# idxmin           Bulgaria     Germany  United States
# idxmax              Malta  Montenegro          Chile
# world_pop_fract       90%         65%            57%

# %% [markdown]
# When eliminating countries where factor exceeds 10 there 146 countries where the GDP to passenger number factor remains within the limit. This amounts for 95% of the worlds population This do not consider the size of the GDP of specific countr nor the population. Below I will use population and GDP as a limit

# %% [markdown]
# ### Plotting year 2018

# %%
# GDPvsPSGR align factors PLOTs
adjusted = EDA_results['2018']['GDP_vs_PSGR']['adjusted']

# plot_GDP_PSGR_2018_align_factor(data_2018)
# plot_GDP_PSGR_2018_align_factor(adjusted[thr1])
# plot_GDP_PSGR_2018_align_factor(adjusted[thr2])
# plot_GDP_PSGR_2018_align_factor(adjusted[thr3])

# %%
args_A = ('GDP_2018', 'PSGR_2018')
adjusted1_slice = keep_selected_columns(adjusted[thr1], *args_A )
adjusted2_slice = keep_selected_columns(adjusted[thr2], *args_A )
adjusted3_slice = keep_selected_columns(adjusted[thr3], *args_A )

# GDP_PSGR_2018_copy = GDP_PSGR_2018_top.copy().drop(['GDP_to_PSGR_2018','SURF_2018', 'GDP_PCAP_2018', 'POP_2018'], axis=1)  # Create a copy of the DataFrame
# GDP_PSGR_2018_copy2 = GDP_PSGR_2018_top.copy().drop(['GDP_to_PSGR_2018','PSGR_2018', 'GDP_PCAP_2018', 'POP_2018',], axis=1)  # Create a copy of the DataFrame
# Normalize the data

factA=1e12
factB=factA/refRatioGDP_to_PSGR2018 
args_B = ('GDP_2018','PSGR_2018',factA,factB)
adjusted1_normalized = normalize_to_plot(adjusted1_slice,*args_B)
adjusted2_normalized = normalize_to_plot(adjusted2_slice,*args_B)
adjusted3_normalized = normalize_to_plot(adjusted3_slice,*args_B)

# %%
sort_by = "GDP_2018"
adjusted1_normalized = adjusted1_normalized.sort_values(by=sort_by, ascending=False)
adjusted2_normalized = adjusted2_normalized.sort_values(by=sort_by, ascending=False)
adjusted3_normalized = adjusted3_normalized.sort_values(by=sort_by, ascending=False)
###REF
plot_GDP_vs_PSGR(adjusted1_normalized.iloc[3:75])

plot_GDP_vs_PSGR(adjusted2_normalized.iloc[3:75], "darkslateblue", "red")
plot_GDP_vs_PSGR(adjusted2_normalized.iloc[40:100],"darkslateblue", "gray")

plot_GDP_vs_PSGR(adjusted3_normalized.iloc[3:],"darkslateblue","yellow")
plot_GDP_vs_PSGR(adjusted3_normalized.iloc[20:],"darkslateblue","yellow")

# plot_GDP_vs_PSGR(adjusted1_normalized[:30])
# plot_GDP_vs_PSGR(adjusted1_normalized.iloc[30:60])
# plot_GDP_vs_PSGR(adjusted1_normalized.iloc[60:90])
# plot_GDP_vs_PSGR(adjusted1_normalized.iloc[90:120])

# %% [markdown]
# ### Comparing POP, SURF and GDP_PCAP to PSGR

# %%
SURF_PSGR_2018 = data_2018.copy()
## Selected dataframe
SURF_PSGR_2018 = keep_selected_columns(SURF_PSGR_2018, 'SURF_2018', 'PSGR_2018','POP_2018' )

# %%
# Reference country
ref_country = "China"

# Genereating GDP to SURF align factor
SURF_PSGR_2018, ref_ratio_SURFvsPSGR, ref_SURF, ref_PSGR =generate_align_factor(SURF_PSGR_2018, "SURF_2018", "PSGR_2018",ref_country)

# Sorting data by SURF
SURF_PSGR_2018 = SURF_PSGR_2018.sort_values(by="SURF_2018", ascending=False)

# SURF_PSGR_2018

# %%
# Filtering countries by the GDP to SURF align factor
_, df_filtered_surf1, _ = exclude_to_high_factor_countries(SURF_PSGR_2018,'SURF_to_PSGR_2018',ithr1)
_, df_filtered_surf2, _ = exclude_to_high_factor_countries(SURF_PSGR_2018,'SURF_to_PSGR_2018',ithr2)
_, df_filtered_surf3, _ = exclude_to_high_factor_countries(SURF_PSGR_2018,'SURF_to_PSGR_2018',ithr3)
# df_f => df_filtered

# %%
def print_stats(df, world_pop):
    series = df['SURF_to_PSGR_2018']
    print(f"\nMin:{series.min()}, max: {series.max()} (align factor)")
    print(series.describe())
    print_world_population_factor(world_pop, df['POP_2018'], True)
    



# # 100% of the data
# print_stats(SURF_PSGR_2018, world_pop_2018)    
# #filtered by threshold
# print_stats(df_filtered_surf1, world_pop_2018)
# print_stats(df_filtered_surf2, world_pop_2018)
# print_stats(df_filtered_surf3, world_pop_2018)

# %%
def get_stats(df,col_name, world_pop, pop_col_name):
    series = df[col_name]
    s_min = pd.Series([series.min()], index=["Min."])
    s_max = pd.Series([series.max()], index=['Max.'])
    s_std = pd.Series([series.std()], index=['Std.'])
    s_count = pd.Series([series.count()], index=["Count"])
    s_mean = pd.Series([series.mean()],index=['Mean'])

    ratio = print_world_population_factor(world_pop, df[pop_col_name],prnt =False)
    s_w_pop_ratio = pd.Series([ratio], index=["world_pop_ratio"])
    
    s_stats = pd.concat([s_min, s_max, s_std, s_count, s_mean, s_w_pop_ratio])
    
    return s_stats
    
args_stats__SURF_vs_PSGR = "SURF_to_PSGR_2018", world_pop_2018, "POP_2018" 
statsAll = get_stats(SURF_PSGR_2018,*args_stats__SURF_vs_PSGR) 
stats1 = get_stats(df_filtered_surf1,*args_stats__SURF_vs_PSGR) 
stats2 = get_stats(df_filtered_surf2,*args_stats__SURF_vs_PSGR) 
stats3 = get_stats(df_filtered_surf3,*args_stats__SURF_vs_PSGR) 



# Creating stats dataframe
df_input = [statsAll, stats1, stats2, stats3]

index = ["All",
          str_to_percentage(thr1),
          str_to_percentage(thr2),
          str_to_percentage(thr3)]

stats_df__SURF_vs_PSGR =pd.DataFrame(df_input, index=index).transpose()

# Converting dataframe rows to different types
def df_row__float_to_int(df, index_name): 
    # Transpose the DataFrame
    df_t = df.transpose()

    # Convert the 'world_pop_fract' column to percentage, round to 0 decimal digits, and convert to string
    df_t[index_name] = df_t[index_name].apply(lambda x: int(x) if isinstance(x, float) else x)

    # Transpose back to the original structure
    df = df_t.transpose()
    
    return df

def apply_to_all_rows_except(df, excluded_row):
    """
    Converts values in every row to the percentage except excluded row.
    
    df -   input DataFrame.
    excluded_row (str): The name of the row to exclude.

    returns converted dataframe
    
    """
    for row in df.index:
        if row != excluded_row:
            df = df_row__float_to_percent(df, row)

    return df

# Apply the function to the DataFrame
stats_df__SURF_vs_PSGR = apply_to_all_rows_except(stats_df__SURF_vs_PSGR, "Count")
stats_df__SURF_vs_PSGR = df_row__float_to_int(stats_df__SURF_vs_PSGR,"Count")

stats_df__SURF_vs_PSGR
# Out:
#                       All   250%  100%   25%
# Min.             -288092%  -250%  -94%  -19%
# Max.              154832%   236%   90%   19%
# Std.               31442%   120%   53%   11%
# Count                 155     57    28     8
# Mean               -3645%   -11%   -8%   -3%
# world_pop_ratio       96%    61%   49%   22%

# %%
# Plot for ALL countries
# SURF_PSGR_2018 contains all data
# df_filtered_surf.. contains filtered by threshold data of SURF_PSGR_2018

plot_one_vs_other(SURF_PSGR_2018,"SURF_2018", "PSGR_2018", ref_country,ref_SURF, ref_PSGR, colorA="lightblue", colorB="red")
# Plot for ALL countries but 6 largest in SURF
plot_one_vs_other(SURF_PSGR_2018[6:],"SURF_2018", "PSGR_2018", ref_country, ref_SURF, ref_PSGR, colorA="lightblue", colorB="red")


# ## Plots for lower thresholds
# plot_one_vs_other(df_filtered_surf1,"SURF_2018", "PSGR_2018", ref_country, ref_SURF, ref_PSGR)
# plot_one_vs_other(df_filtered_surf2,"SURF_2018", "PSGR_2018", ref_country, ref_SURF, ref_PSGR)
# plot_one_vs_other(df_filtered_surf3,"SURF_2018", "PSGR_2018", ref_country, ref_SURF, ref_PSGR)

# %% [markdown]
#  When excluding 6 biggest countries there is not much visible corelation of the SURF to PSGR.
#  This can be seen in the statistics also:

# %%
# 100% of the data
print_stats(SURF_PSGR_2018[6:], world_pop_2018)    
#filtered by threshold
print_stats(df_filtered_surf1[6:], world_pop_2018)
print_stats(df_filtered_surf2[6:], world_pop_2018)
print_stats(df_filtered_surf3[6:], world_pop_2018)
# Out:
# Min:-2880.92, max: 1548.32 (align factor)
# count     149.000000
# mean      -37.752886
# std       320.661079
# min     -2880.920000
# 25%       -15.970000
# 50%        -1.470000
# 75%         1.190000
# max      1548.320000
# Name: SURF_to_PSGR_2018, dtype: float64
# 68% of world population in year 2018
# 		("print_world_population_factor" function.)
#
# Min:-2.5, max: 2.36 (align factor)
# count    51.000000
# mean     -0.063137
# std       1.226449
# min      -2.500000
# 25%      -1.070000
# 50%      -0.120000
# 75%       1.040000
# max       2.360000
# Name: SURF_to_PSGR_2018, dtype: float64
# 15% of world population in year 2018
# 		("print_world_population_factor" function.)
#
# Min:-0.89, max: 0.9 (align factor)
# count    22.000000
# mean     -0.088636
# std       0.549253
# min      -0.890000
# 25%      -0.597500
# 50%      -0.125000
# 75%       0.380000
# max       0.900000
# Name: SURF_to_PSGR_2018, dtype: float64
# 4% of world population in year 2018
# ...

# %% [markdown]
# # AIRPORTS analysis <a id="AIRPORTS_analysis"></a> 🔗

# %%
# airports.head(5)

# %%
# New dataframe containing country name and all airport_idents in that country. Each ident can mean an airport/helipad or orther type of landing filed
country_airports = airports.groupby('country_name')['ident'].apply(list).reset_index()

# %%
apts_by_index = country_airports.set_index('country_name')
#apts_by_index

# %%
# First 10 airports
# apts_by_index.loc['Poland'].ident[:10]

# %%
len(apts_by_index.loc['Poland'].ident)

# %% [markdown]
# #### Merging airports dataframe with runway dataframe

# %%
# airports

# %%
# runways

# %%
### MERGING airports and runways dataframes
apt_and_rwys= pd.merge(airports, runways, left_on='ident', right_on='airport_ident')
apt_and_rwys.shape

# %%
max_col_OFF()
# apt_and_rwys.head(6)

# %%
selected_apt = apt_and_rwys[apt_and_rwys['ident'] == 'EPWA']

# %%
# selected_apt

# %%
# [x for x in apt_and_rwys.head(0)]

# %%
 #Check if 'ident' and 'airport_ident' columns are equal
print(len(apt_and_rwys['ident']), len(apt_and_rwys['airport_ident']))
are_equal = (apt_and_rwys['ident'] == apt_and_rwys['airport_ident']).all()
are_equal

# %%
# Removing "airport_ident" column from the dataframe 
apt_and_rwys2 = apt_and_rwys.drop('airport_ident', axis=1)

# %%
# Drop not required columns
apt_and_rwys3 = apt_and_rwys2.drop(['id_x','local_region','gps_code','home_link','keywords','score','id_y','last_updated','local_code','airport_ref'], axis=1)

# %%
apt_and_rwys3.shape

# %%
max_col_OFF()
# apt_and_rwys3.head(3)

# %%
# [x for x in apt_and_rwys3.head(0)]

# %%
schedule_service_only_apts = apt_and_rwys3[apt_and_rwys3['scheduled_service'] == 1]
stripped = schedule_service_only_apts["ident"].squeeze()
only_sheduled_services_apts_ident = stripped.drop_duplicates()

only_sheduled_services_apts_ident.to_json("Modified_data/only_scheduled.json", orient="records")

# %%
import json
with open('Modified_data/only_scheduled.json', "r") as file:
    data = json.load(file)

# %%
idents_only = schedule_service_only_apts.drop_duplicates(subset='ident')
# CHecking unique values for some columns
unique_values = set(apt_and_rwys3['type'].unique())
print(unique_values)

# %%
unique_values = set(apt_and_rwys3['continent'].unique())
unique_values

# %%
# apt_and_rwys3.head(3)

# %%
# CHecking how reliable is "continent column"
nan_count_in_continent = apt_and_rwys3['continent'].isna().sum()
nan_count_in_continent

# %% [markdown]
# There are thousends of airports, including major ones (e.g. KLAX that is Los Angeles) where the continent data is NaN. This means that I cannot rely very much to recognise the continent on which selected airport lies.

# %%
nan_count = apt_and_rwys3['surface'].isna().sum()
nan_count

# %%
# Since there is more tha fifteen thousand of NaNs in "continent" column, that makes it unreliable data, so I remove it from the dataset
apt_and_rwys4 = apt_and_rwys3.drop([ "municipality"], axis=1)
# apt_and_rwys4.head(5)

# %%
df = apt_and_rwys4
df_180 = df[df['le_heading_degT'] == 180]

print(df_180[['ident','length_ft']])

# %%
# apt_and_rwys4.head(3)
# df_180[df_180[""]]
# Reordering columns 
apt_and_rwys5 = pd.DataFrame(apt_and_rwys4,columns=['ident','iata_code','type','iso_country','country_name'])

# %%
types = apt_and_rwys5.groupby(['country_name', 'type']).size()

types["Cuba"]

# %%
cols_to_move = ['ident','iata_code','type','iso_country','country_name']
new_cols = cols_to_move + [col for col in apt_and_rwys4.columns if col not in cols_to_move]
apt_and_rwys5 = pd.DataFrame(apt_and_rwys4,columns=new_cols)

# %% [markdown]
# ### Runways - GRAPHS

# %%
df = apt_and_rwys4
df = df[df['continent'] == 'EU']
df = df[df['le_heading_degT'].between(0, 180)]

# now create a histogram with seaborn
plt.figure(figsize=(10,6))
sns.histplot(df['le_heading_degT'], bins=180, kde=False)

plt.title('Distribution of le_heading_degT - WORLD')
plt.xlabel('le_heading_degT (in degrees)')
plt.ylabel('Count')
plt.show()

# %%
df = apt_and_rwys4
df = df[df['country_name'] == 'United States']
# df = df[df['le_heading_degT'].between(0, 180)]

## FILTERING AIRPORTS WHICH HAS le heading and no he heading
df = df[df['le_heading_degT'].between(0, 180) & df['he_heading_degT'].notna()]
# df = df[df['he_heading_degT'].notna()]
print(df.shape)


# now create a histogram with seaborn
plt.figure(figsize=(10,6))
sns.histplot(df['le_heading_degT'], bins=180, kde=False)

plt.title('Distribution of le_heading_deg - US')
plt.xlabel('le_heading_degT (in degrees)')
plt.ylabel('Count')
plt.show()

# %%
df_180[df_180["type"]=="medium_airport"]

# %%
df=df_180
df['length_rounded'] = df['length_ft'].apply(lambda x: int(np.round(x, -3)))

# count number of airports for each rounded length
df_count = df.groupby('length_rounded').size().reset_index(name='airport_count')

# create plot
plt.figure(figsize=(10, 6))
sns.barplot(x='length_rounded', y='airport_count', data=df_count, color='b')
plt.xlabel('Runway Length (ft, rounded to nearest 1000)')
plt.ylabel('Number of Airports')
plt.title('Number of Airports by Runway Length[ft] with the direction of 180deg')
plt.xticks(rotation=45)
plt.show()

# %%
df = apt_and_rwys4
df = df[df['country_name'] == 'China']
df = df[df['le_heading_degT'].between(0, 180)]

# now create a histogram with seaborn
plt.figure(figsize=(10,6))
sns.histplot(df['le_heading_degT'], bins=9, kde=False)

plt.title('Distribution of le_heading_degT')
plt.xlabel('le_heading_degT (in degrees)')
plt.ylabel('Count')
plt.show()

# %%
## Converting from "wide format" to long format
df = worldbank_PSGR_raw
df_melted = df.melt(
    id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], 
    value_vars=[str(i) for i in range(1960, 2023)],  # list the years here
    var_name='Year', 
    value_name='Value'
)

# filter out rows where 'Value' is NaN
df_melted = df_melted.dropna(subset=['Value'])
# df_melted

# %%
## Printing countries names to see check what convention is used to call each 

# [print(x) for x in countries]



## Preparing PSGR_number to display on the year/PSGR_number initial plot

# Convert 'Year' to integer
df_melted['Year'] = df_melted['Year'].astype(int)

# List of countries to keep
countries_to_keep = ['Italy',"Germany", "Netherlands","United Kingdom" ]

# Filter dataframe
df_filtered = df_melted[df_melted['Country Name'].isin(countries_to_keep)]

### PLOTTING PSGR_NUM vs YEAR for SELECTED COUNTRIES
g=sns.relplot(kind="line",x="Year",y="Value", hue="Country Name",errorbar=None, data=df_filtered )

# Access the underlying matplotlib axes
ax = g.axes[0, 0]

# Format the y-axis tick labels with commas every thousand
ax.yaxis.set_major_formatter(mticker.StrMethodFormatter('{x:,.0f}'))

# Display the plot
plt.show()
